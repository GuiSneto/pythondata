# %%
#importando a biblioteca pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf

sns.set(style='whitegrid')

# %%
#carregar arquivo csv
#vai converter o arquivo em um dataframe(df)

df = pd.read_csv("CONSISTENCIA_ENEM_ESCOLA_2013.csv")
# Out:
#         ID_ENEM_ESCOLA  NU_INSCRICAO  NU_ANO  COD_ESCOLA  COD_UF_ESC  \
# 0                    1  130005767149    2013    11000058          11
# 1                    2  130005864399    2013    11000058          11
# 2                    3  130005948556    2013    11000058          11
# 3                    4  130006015849    2013    11000058          11
# 4                    5  130006076234    2013    11000058          11
# 5                    6  130006109389    2013    11000058          11
# 6                    7  130006132871    2013    11000058          11
# 7                    8  130006163723    2013    11000058          11
# 8                    9  130006190367    2013    11000058          11
# 9                   10  130006217511    2013    11000058          11
# 10                  11  130006244317    2013    11000058          11
# 11                  12  130006256054    2013    11000058          11
# 12                  13  130006333753    2013    11000058          11
# ...

# %%
# mostra um resumo do arquivo
df
# Out:
#         ID_ENEM_ESCOLA  NU_INSCRICAO  NU_ANO  COD_ESCOLA  COD_UF_ESC  \
# 0                    1  130005767149    2013    11000058          11
# 1                    2  130005864399    2013    11000058          11
# 2                    3  130005948556    2013    11000058          11
# 3                    4  130006015849    2013    11000058          11
# 4                    5  130006076234    2013    11000058          11
# 5                    6  130006109389    2013    11000058          11
# 6                    7  130006132871    2013    11000058          11
# 7                    8  130006163723    2013    11000058          11
# 8                    9  130006190367    2013    11000058          11
# 9                   10  130006217511    2013    11000058          11
# 10                  11  130006244317    2013    11000058          11
# 11                  12  130006256054    2013    11000058          11
# 12                  13  130006333753    2013    11000058          11
# ...

# %%
# mostra as 5 primeiras linhas

df. head()
# Out:
#    ID_ENEM_ESCOLA  NU_INSCRICAO  NU_ANO  COD_ESCOLA  COD_UF_ESC  \
# 0               1  130005767149    2013    11000058          11
# 1               2  130005864399    2013    11000058          11
# 2               3  130005948556    2013    11000058          11
# 3               4  130006015849    2013    11000058          11
# 4               5  130006076234    2013    11000058          11
#
#    ID_LOCALIZACAO_ESC  ID_DEPENDENCIA_ADM_ESC
# 0                   1                       4
# 1                   1                       4
# 2                   1                       4
# 3                   1                       4
# 4                   1                       4

# %%
# ultimas 5 linhas
df.tail()
# Out:
#         ID_ENEM_ESCOLA  NU_INSCRICAO  NU_ANO  COD_ESCOLA  COD_UF_ESC  \
# 878848          878849  130012823608    2013    53068181          53
# 878849          878850  130012827474    2013    53068181          53
# 878850          878851  130012829394    2013    53068181          53
# 878851          878852  130012865488    2013    53068181          53
# 878852          878853  130012895451    2013    53068181          53
#
#         ID_LOCALIZACAO_ESC  ID_DEPENDENCIA_ADM_ESC
# 878848                   1                       2
# 878849                   1                       2
# 878850                   1                       2
# 878851                   1                       2
# 878852                   1                       2

# %%
# escolher o intervalo de linhas e quantidades de coluna

df.iloc [100:150,:2]
# Out:
#      ID_ENEM_ESCOLA  NU_INSCRICAO
# 100             101  130010330673
# 101             102  130010339803
# 102             103  130010376798
# 103             104  130010380921
# 104             105  130010404968
# 105             106  130010405488
# 106             107  130010495366
# 107             108  130010647294
# 108             109  130010676323
# 109             110  130010684065
# 110             111  130010689259
# 111             112  130010694321
# 112             113  130010757333
# 113             114  130010818467
# 114             115  130010918109
# 115             116  130010973291
# 116             117  130011109931
# 117             118  130011133727
# 118             119  130011161634
# 119             120  130011189371
# 120             121  130011209981
# 121             122  130011450227
# 122             123  130011488036
# 123             124  130011491850
# 124             125  130011539635
# 125             126  130011630391
# ...

# %%
#nome das colunas no conjunto de dados
df.columns
# Out:
# Index(['ID_ENEM_ESCOLA', 'NU_INSCRICAO', 'NU_ANO', 'COD_ESCOLA', 'COD_UF_ESC',
#        'ID_LOCALIZACAO_ESC', 'ID_DEPENDENCIA_ADM_ESC'],
#       dtype='object')

# %%
#contar as linhs de cada coluna?
df.count()
# Out:
# ID_ENEM_ESCOLA            878853
# NU_INSCRICAO              878853
# NU_ANO                    878853
# COD_ESCOLA                878853
# COD_UF_ESC                878853
# ID_LOCALIZACAO_ESC        878853
# ID_DEPENDENCIA_ADM_ESC    878853
# dtype: int64

# %%
#resumo estatístico
df.ID_LOCALIZACAO_ESC.describe()
# Out:
# count    878853.000000
# mean          1.021388
# std           0.144674
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           2.000000
# Name: ID_LOCALIZACAO_ESC, dtype: float64

# %%
# mediana
df.NU_ANO.median()
# Out:
# 2013.0

# %%
#valor max
df.NU_ANO.max()
# Out:
# 2013

# %%
#valor minimo

df.NU_ANO.min()
# Out:
# 2013

# %%
#média
df.NU_ANO.mean()
# Out:
# 2013.0

# %%
df.dtypes
# Out:
# ID_ENEM_ESCOLA            int64
# NU_INSCRICAO              int64
# NU_ANO                    int64
# COD_ESCOLA                int64
# COD_UF_ESC                int64
# ID_LOCALIZACAO_ESC        int64
# ID_DEPENDENCIA_ADM_ESC    int64
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-8061bcc6b424> in <module>
#       1 # mediana
#       2
# ----> 3 df.cpr.median()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'cpr'
